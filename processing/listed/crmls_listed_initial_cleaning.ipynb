# %% [markdown]
# ## Basic data cleaning for each dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("../raw/listed/CRMLSListing202402.csv")
display(df.head())
display(df.info())
display(df.shape)
# Out:
#    OriginalListPrice  ListingKey              ListAgentEmail CloseDate  \
# 0             1000.0   421654881    luann.hall@sbcglobal.net       NaN
# 1           799999.0  1075011484  Christina.sdsu12@gmail.com       NaN
# 2           820000.0  1075000634          ethan@c2realty.com       NaN
# 3          1300000.0  1074997455            jportillo@kw.com       NaN
# 4           489999.0  1074990034     corey@murphyhousing.com       NaN
#
#    ClosePrice ListAgentFirstName ListAgentLastName   Latitude   Longitude  \
# 0         NaN             Lu Ann              Hall  33.138645 -117.180289
# 1         NaN          Christina              Diab        NaN         NaN
# 2         NaN              Ethan              Kolb  37.340056 -120.434070
# 3         NaN              Jason          Portillo  34.577993 -118.154162
# 4         NaN              Corey            Murphy  33.141744 -117.091877
#
#             UnparsedAddress  ... MainLevelBedrooms  NewConstructionYN  \
# ...

# %%
for col in df.columns:
    if col.endswith('.1'):
        base_col = col[:-2]
        if base_col in df.columns:
            print(base_col, df[base_col].equals(df[col]))
# Out:
# PropertyType True
# ListAgentFirstName True
# DaysOnMarket True
# LivingArea True
# Longitude True
# Latitude True
# ListPrice True
# ListAgentLastName True
# CloseDate True
# BuyerOfficeName True
# UnparsedAddress True

# %%
df[df['ListPrice'] != df['ListPrice.1']][['ListPrice', 'ListPrice.1']]
# Out:
#        ListPrice  ListPrice.1
# 126          NaN          NaN
# 461          NaN          NaN
# 547          NaN          NaN
# 930          NaN          NaN
# 932          NaN          NaN
# ...          ...          ...
# 25669        NaN          NaN
# 25696        NaN          NaN
# 25858        NaN          NaN
# 26020        NaN          NaN
# 26727        NaN          NaN
#
# [71 rows x 2 columns]
